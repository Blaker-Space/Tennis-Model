# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow import keras
from tensorflow.keras import layers

from keras.models import Sequential
from keras.layers import Convolution2D, Dropout, Dense, GRU
from keras.layers import BatchNormalization
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import LeakyReLU
from keras.callbacks import ModelCheckpoint

from tqdm import tqdm

# %%
import os
import cv2
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

X=[]
y=[]

folders = ["nadal", "djoko_sock", "federer", "alcaraz", "dimitrov_alcaraz", "dimitrov_thiem", "roland"]

for folder in folders:
    if not os.path.exists(f"dataset/{folder}/shots/"):
        print(f"dataset/{folder}/shots/ doesnt exist")
        continue
        
    print(f"Loading shots from dataset/{folder}/shots/")
        
    for shot_csv in tqdm(sorted(os.listdir(f'dataset/{folder}/shots/'))):
        data = pd.read_csv(os.path.join(f'dataset/{folder}/shots/', shot_csv))
        
        if folder == "nadal":
            revert_data= data.copy()
            for feature in data.columns:
                if feature[-2:]=="_x":
                    revert_data[feature] = 1 - data[feature]
            data = revert_data

        features = data.loc[:, data.columns != 'shot']

        X.append(features.to_numpy())
        y.append(data["shot"].iloc[0])
    
X = np.stack(X, axis=0)

y = np.array(y)
X = np.array(X)

print(f"Loaded {len(y)} shots for training")

X_test=[]
y_test=[]

folders = ["roland", "alcaraz"]
for folder in folders:
    for shot_csv in sorted(os.listdir(f'dataset/{folder}/shots/')):
    
        data = pd.read_csv(os.path.join(f'dataset/{folder}/shots/',shot_csv ))

        if folder == "dataset_nadal":
                revert_data= data.copy()
                for feature in data.columns:
                    if feature[-2:]=="_x":
                        revert_data[feature] = 1 - data[feature]
                data = revert_data


        features = data.loc[:, data.columns != 'shot']

        X_test.append(features.to_numpy())
        y_test.append(data["shot"].iloc[0])
    
X_test = np.stack(X_test, axis=0)

y_test = np.array(y_test)
X_test = np.array(X_test)

print(f"Loaded {len(y_test)} shots for test")
# Out:
# Loading shots from dataset/nadal/shots/
# 100%|███████████████████████████████████████████████████████████████████████████████| 442/442 [00:03<00:00, 140.98it/s]
# Loading shots from dataset/djoko_sock/shots/
# 100%|███████████████████████████████████████████████████████████████████████████████| 247/247 [00:00<00:00, 406.56it/s]
# Loading shots from dataset/federer/shots/
# 100%|███████████████████████████████████████████████████████████████████████████████| 325/325 [00:00<00:00, 421.11it/s]
# Loading shots from dataset/alcaraz/shots/
# 100%|███████████████████████████████████████████████████████████████████████████████| 129/129 [00:00<00:00, 425.73it/s]
# dataset/dimitrov_alcaraz/shots/ doesnt exist
# Loading shots from dataset/dimitrov_thiem/shots/
# 100%|███████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 411.13it/s]
# Loading shots from dataset/roland/shots/
# 100%|█████████████████████████████████████████████████████████████████████████████████| 64/64 [00:00<00:00, 345.54it/s]
# Loaded 1350 shots for training
# Loaded 193 shots for test

# %%
from sklearn.model_selection import train_test_split

# Split the data
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.33, shuffle= True)


print(f"Shape of train features : {X_train[0].shape}")
print(f"Shape of val features : {X_val[0].shape}")

print("Total categories: ", len(np.unique(y_train)))
print("Total categories: ", len(np.unique(y_val)))

nb_cat = len(np.unique(y_train))
# Out:
# Shape of train features : (30, 26)
# Shape of val features : (30, 26)
# Total categories:  4
# Total categories:  4

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

y_train = le.fit_transform(y_train)
y_val = le.fit_transform(y_val)
y_test = le.fit_transform(y_test)

y_train = tf.keras.utils.to_categorical(y_train, num_classes=nb_cat)
y_val = tf.keras.utils.to_categorical(y_val, num_classes=nb_cat)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=nb_cat)

y_train = np.array(y_train)
X_train = np.array(X_train)
#X_train = np.expand_dims(X_train, axis=-1)

y_val = np.array(y_val)
X_val = np.array(X_val)
#X_val = np.expand_dims(X_val, axis=-1)

y_test = np.array(y_test)
X_test = np.array(X_test)

# %%
assert len(le.classes_) == nb_cat

# %%
print("X_train Shape: ", X_train.shape)
print("X_val Shape: ", X_val.shape)
print("X_test Shape: ", X_test.shape)
print("y_train Shape: ", y_train.shape)
print("y_val Shape: ", y_val.shape)
print("y_test Shape: ", y_test.shape)
# Out:
# X_train Shape:  (904, 30, 26)
# X_val Shape:  (446, 30, 26)
# X_test Shape:  (193, 30, 26)
# y_train Shape:  (904, 4)
# y_val Shape:  (446, 4)
# y_test Shape:  (193, 4)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

model = Sequential()
model.add(LSTM(units=24, dropout=0.1, recurrent_dropout=0.1, input_shape=(30, 26)))
model.add(Dropout(0.2))
model.add(Dense(units=8, activation='relu'))
model.add(Dense(units=nb_cat, activation='softmax'))

m1.compile(optimizer='adam', loss = 'categorical_crossentropy',metrics = ['accuracy'])
m1.summary()

hist = m1.fit(X_train, y_train,
               validation_data=(X_val, y_val),
               batch_size = 32,
                epochs=300, 
                verbose = 1
             )
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru (GRU)                            │ (None, 24)                  │           3,744 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 24)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 8)                   │             200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │              36 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,980 (15.55 KB)
#  Trainable params: 3,980 (15.55 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.9528 - loss: 0.1456 - val_accuracy: 0.9529 - val_loss: 0.1876
# Epoch 2/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9574 - loss: 0.1525 - val_accuracy: 0.9529 - val_loss: 0.1914
# Epoch 3/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9439 - loss: 0.1513 - val_accuracy: 0.9327 - val_loss: 0.2341
# Epoch 4/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9592 - loss: 0.1049 - val_accuracy: 0.9439 - val_loss: 0.2003
# Epoch 5/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9536 - loss: 0.1612 - val_accuracy: 0.9507 - val_loss: 0.1736
# Epoch 6/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9676 - loss: 0.1102 - val_accuracy: 0.9529 - val_loss: 0.1600
# Epoch 7/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9592 - loss: 0.1345 - val_accuracy: 0.9507 - val_loss: 0.1855
# Epoch 8/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9609 - loss: 0.1480 - val_accuracy: 0.9507 - val_loss: 0.1813
# Epoch 9/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9707 - loss: 0.1053 - val_accuracy: 0.9529 - val_loss: 0.1770
# Epoch 10/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9583 - loss: 0.1478 - val_accuracy: 0.9484 - val_loss: 0.1861
# Epoch 11/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9700 - loss: 0.1315 - val_accuracy: 0.9552 - val_loss: 0.1718
# Epoch 12/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9504 - loss: 0.1366 - val_accuracy: 0.9484 - val_loss: 0.1909
# Epoch 13/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9670 - loss: 0.1236 - val_accuracy: 0.9439 - val_loss: 0.1982
# Epoch 14/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9633 - loss: 0.1083 - val_accuracy: 0.9552 - val_loss: 0.1891
# Epoch 15/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9499 - loss: 0.1453 - val_accuracy: 0.9529 - val_loss: 0.1957
# Epoch 16/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9581 - loss: 0.1385 - val_accuracy: 0.9238 - val_loss: 0.2516
# Epoch 17/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9516 - loss: 0.1573 - val_accuracy: 0.9036 - val_loss: 0.3427
# Epoch 18/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9510 - loss: 0.1472 - val_accuracy: 0.9350 - val_loss: 0.2401
# Epoch 19/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9509 - loss: 0.1605 - val_accuracy: 0.9462 - val_loss: 0.2158
# Epoch 20/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9604 - loss: 0.1160 - val_accuracy: 0.9574 - val_loss: 0.1748
# Epoch 21/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9520 - loss: 0.1710 - val_accuracy: 0.9283 - val_loss: 0.2164
# Epoch 22/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9641 - loss: 0.1143 - val_accuracy: 0.9529 - val_loss: 0.1795
# Epoch 23/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9559 - loss: 0.1372 - val_accuracy: 0.9552 - val_loss: 0.1815
# Epoch 24/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9546 - loss: 0.1270 - val_accuracy: 0.9529 - val_loss: 0.1768
# Epoch 25/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9570 - loss: 0.1326 - val_accuracy: 0.9327 - val_loss: 0.2170
# Epoch 26/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9572 - loss: 0.1554 - val_accuracy: 0.9507 - val_loss: 0.1917
# Epoch 27/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9601 - loss: 0.1208 - val_accuracy: 0.9507 - val_loss: 0.1967
# Epoch 28/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9648 - loss: 0.1242 - val_accuracy: 0.9574 - val_loss: 0.1686
# Epoch 29/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9633 - loss: 0.1331 - val_accuracy: 0.9552 - val_loss: 0.1887
# Epoch 30/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9610 - loss: 0.1238 - val_accuracy: 0.9507 - val_loss: 0.2054
# Epoch 31/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9538 - loss: 0.1410 - val_accuracy: 0.9462 - val_loss: 0.2064
# Epoch 32/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9530 - loss: 0.1469 - val_accuracy: 0.9529 - val_loss: 0.1926
# Epoch 33/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9359 - loss: 0.1928 - val_accuracy: 0.9484 - val_loss: 0.1981
# Epoch 34/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9706 - loss: 0.1158 - val_accuracy: 0.9552 - val_loss: 0.1957
# Epoch 35/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9590 - loss: 0.1290 - val_accuracy: 0.9439 - val_loss: 0.2109
# Epoch 36/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9611 - loss: 0.1317 - val_accuracy: 0.9529 - val_loss: 0.1814
# Epoch 37/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9663 - loss: 0.0999 - val_accuracy: 0.9552 - val_loss: 0.1823
# Epoch 38/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9652 - loss: 0.1233 - val_accuracy: 0.9552 - val_loss: 0.1823
# Epoch 39/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9722 - loss: 0.1034 - val_accuracy: 0.9462 - val_loss: 0.1959
# Epoch 40/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9529 - loss: 0.1405 - val_accuracy: 0.9529 - val_loss: 0.1812
# Epoch 41/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9654 - loss: 0.1095 - val_accuracy: 0.9596 - val_loss: 0.1870
# Epoch 42/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9649 - loss: 0.1233 - val_accuracy: 0.9439 - val_loss: 0.1928
# Epoch 43/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9732 - loss: 0.0973 - val_accuracy: 0.9507 - val_loss: 0.1973
# Epoch 44/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9553 - loss: 0.1627 - val_accuracy: 0.9507 - val_loss: 0.1946
# Epoch 45/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9650 - loss: 0.1038 - val_accuracy: 0.9439 - val_loss: 0.2227
# Epoch 46/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9607 - loss: 0.1149 - val_accuracy: 0.9439 - val_loss: 0.2185
# Epoch 47/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9367 - loss: 0.1767 - val_accuracy: 0.9372 - val_loss: 0.2329
# Epoch 48/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9415 - loss: 0.1776 - val_accuracy: 0.9574 - val_loss: 0.1939
# Epoch 49/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9733 - loss: 0.1048 - val_accuracy: 0.9484 - val_loss: 0.1979
# Epoch 50/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9560 - loss: 0.1256 - val_accuracy: 0.9484 - val_loss: 0.2054
# Epoch 51/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9689 - loss: 0.0976 - val_accuracy: 0.9552 - val_loss: 0.1812
# Epoch 52/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9625 - loss: 0.1186 - val_accuracy: 0.9552 - val_loss: 0.1744
# Epoch 53/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9502 - loss: 0.1295 - val_accuracy: 0.9484 - val_loss: 0.2231
# Epoch 54/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9495 - loss: 0.1794 - val_accuracy: 0.9507 - val_loss: 0.1989
# Epoch 55/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9686 - loss: 0.1067 - val_accuracy: 0.9507 - val_loss: 0.1860
# Epoch 56/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9565 - loss: 0.1260 - val_accuracy: 0.9529 - val_loss: 0.1923
# Epoch 57/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9634 - loss: 0.1113 - val_accuracy: 0.9462 - val_loss: 0.1988
# Epoch 58/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9628 - loss: 0.1221 - val_accuracy: 0.9529 - val_loss: 0.1913
# Epoch 59/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9647 - loss: 0.1121 - val_accuracy: 0.9529 - val_loss: 0.1876
# Epoch 60/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9646 - loss: 0.1118 - val_accuracy: 0.9507 - val_loss: 0.1892
# Epoch 61/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9573 - loss: 0.1576 - val_accuracy: 0.9552 - val_loss: 0.1838
# Epoch 62/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9593 - loss: 0.1381 - val_accuracy: 0.9507 - val_loss: 0.1948
# Epoch 63/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9636 - loss: 0.1135 - val_accuracy: 0.9529 - val_loss: 0.1936
# Epoch 64/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9573 - loss: 0.1425 - val_accuracy: 0.9552 - val_loss: 0.1779
# Epoch 65/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9722 - loss: 0.1103 - val_accuracy: 0.9552 - val_loss: 0.1833
# Epoch 66/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9638 - loss: 0.1173 - val_accuracy: 0.9507 - val_loss: 0.1884
# Epoch 67/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9551 - loss: 0.1435 - val_accuracy: 0.9507 - val_loss: 0.1894
# Epoch 68/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9612 - loss: 0.1390 - val_accuracy: 0.9484 - val_loss: 0.2164
# Epoch 69/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9556 - loss: 0.1403 - val_accuracy: 0.9395 - val_loss: 0.2348
# Epoch 70/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9488 - loss: 0.1456 - val_accuracy: 0.9507 - val_loss: 0.1841
# Epoch 71/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9768 - loss: 0.1011 - val_accuracy: 0.9507 - val_loss: 0.2078
# Epoch 72/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9598 - loss: 0.1063 - val_accuracy: 0.9619 - val_loss: 0.1674
# Epoch 73/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9619 - loss: 0.1268 - val_accuracy: 0.9574 - val_loss: 0.1748
# Epoch 74/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9580 - loss: 0.1379 - val_accuracy: 0.9462 - val_loss: 0.1972
# Epoch 75/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9529 - loss: 0.1453 - val_accuracy: 0.9619 - val_loss: 0.1700
# Epoch 76/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9669 - loss: 0.1201 - val_accuracy: 0.9574 - val_loss: 0.1849
# Epoch 77/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9720 - loss: 0.0947 - val_accuracy: 0.9529 - val_loss: 0.1987
# Epoch 78/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9576 - loss: 0.1557 - val_accuracy: 0.9507 - val_loss: 0.2091
# Epoch 79/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9616 - loss: 0.1254 - val_accuracy: 0.9507 - val_loss: 0.2128
# Epoch 80/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9613 - loss: 0.1268 - val_accuracy: 0.9552 - val_loss: 0.1943
# Epoch 81/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9659 - loss: 0.0878 - val_accuracy: 0.9484 - val_loss: 0.2149
# Epoch 82/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9682 - loss: 0.1112 - val_accuracy: 0.9395 - val_loss: 0.2329
# Epoch 83/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9677 - loss: 0.1059 - val_accuracy: 0.9462 - val_loss: 0.2067
# Epoch 84/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9668 - loss: 0.1407 - val_accuracy: 0.9462 - val_loss: 0.2169
# Epoch 85/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9659 - loss: 0.1006 - val_accuracy: 0.9507 - val_loss: 0.2015
# Epoch 86/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9686 - loss: 0.1053 - val_accuracy: 0.9552 - val_loss: 0.1884
# Epoch 87/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9681 - loss: 0.1068 - val_accuracy: 0.9350 - val_loss: 0.2199
# Epoch 88/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9594 - loss: 0.1341 - val_accuracy: 0.9462 - val_loss: 0.2084
# Epoch 89/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9661 - loss: 0.1205 - val_accuracy: 0.9507 - val_loss: 0.2140
# Epoch 90/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9574 - loss: 0.1339 - val_accuracy: 0.9641 - val_loss: 0.1694
# Epoch 91/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9523 - loss: 0.1257 - val_accuracy: 0.9596 - val_loss: 0.1731
# Epoch 92/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9569 - loss: 0.1342 - val_accuracy: 0.9462 - val_loss: 0.2026
# Epoch 93/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9604 - loss: 0.1284 - val_accuracy: 0.9529 - val_loss: 0.1826
# Epoch 94/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9562 - loss: 0.1481 - val_accuracy: 0.9529 - val_loss: 0.1908
# Epoch 95/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9652 - loss: 0.1197 - val_accuracy: 0.9574 - val_loss: 0.1692
# Epoch 96/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9688 - loss: 0.1184 - val_accuracy: 0.9507 - val_loss: 0.2008
# Epoch 97/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9631 - loss: 0.1080 - val_accuracy: 0.9552 - val_loss: 0.2137
# Epoch 98/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9639 - loss: 0.1263 - val_accuracy: 0.9529 - val_loss: 0.1877
# Epoch 99/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9621 - loss: 0.1171 - val_accuracy: 0.9529 - val_loss: 0.1825
# Epoch 100/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9625 - loss: 0.1196 - val_accuracy: 0.9552 - val_loss: 0.1740
# Epoch 101/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9764 - loss: 0.0895 - val_accuracy: 0.9484 - val_loss: 0.2019
# Epoch 102/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9829 - loss: 0.0810 - val_accuracy: 0.9529 - val_loss: 0.1991
# Epoch 103/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9749 - loss: 0.0806 - val_accuracy: 0.9439 - val_loss: 0.2419
# Epoch 104/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9671 - loss: 0.1106 - val_accuracy: 0.9596 - val_loss: 0.1764
# Epoch 105/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9673 - loss: 0.1102 - val_accuracy: 0.9596 - val_loss: 0.1683
# Epoch 106/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9738 - loss: 0.0937 - val_accuracy: 0.9552 - val_loss: 0.1710
# Epoch 107/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9605 - loss: 0.1170 - val_accuracy: 0.9529 - val_loss: 0.1855
# Epoch 108/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9798 - loss: 0.0935 - val_accuracy: 0.9507 - val_loss: 0.1895
# Epoch 109/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9780 - loss: 0.0665 - val_accuracy: 0.9574 - val_loss: 0.1780
# Epoch 110/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9568 - loss: 0.1397 - val_accuracy: 0.9372 - val_loss: 0.2501
# Epoch 111/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9554 - loss: 0.1383 - val_accuracy: 0.9552 - val_loss: 0.1745
# Epoch 112/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9684 - loss: 0.1040 - val_accuracy: 0.9552 - val_loss: 0.1812
# Epoch 113/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9650 - loss: 0.1082 - val_accuracy: 0.9596 - val_loss: 0.1729
# Epoch 114/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9651 - loss: 0.1056 - val_accuracy: 0.9529 - val_loss: 0.1969
# Epoch 115/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9746 - loss: 0.0917 - val_accuracy: 0.9596 - val_loss: 0.1651
# Epoch 116/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9739 - loss: 0.0792 - val_accuracy: 0.9596 - val_loss: 0.1734
# Epoch 117/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9694 - loss: 0.1056 - val_accuracy: 0.9552 - val_loss: 0.1725
# Epoch 118/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9663 - loss: 0.1016 - val_accuracy: 0.9507 - val_loss: 0.2150
# Epoch 119/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9793 - loss: 0.0859 - val_accuracy: 0.9552 - val_loss: 0.1878
# Epoch 120/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9748 - loss: 0.0762 - val_accuracy: 0.9574 - val_loss: 0.1781
# Epoch 121/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9629 - loss: 0.0986 - val_accuracy: 0.9552 - val_loss: 0.1704
# Epoch 122/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9653 - loss: 0.1450 - val_accuracy: 0.9484 - val_loss: 0.2155
# Epoch 123/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9700 - loss: 0.1060 - val_accuracy: 0.9507 - val_loss: 0.1735
# Epoch 124/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9738 - loss: 0.0988 - val_accuracy: 0.9529 - val_loss: 0.1831
# Epoch 125/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9859 - loss: 0.0678 - val_accuracy: 0.9529 - val_loss: 0.1899
# Epoch 126/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9585 - loss: 0.1249 - val_accuracy: 0.9484 - val_loss: 0.1872
# Epoch 127/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9621 - loss: 0.1116 - val_accuracy: 0.9574 - val_loss: 0.1885
# Epoch 128/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9719 - loss: 0.0879 - val_accuracy: 0.9507 - val_loss: 0.1864
# Epoch 129/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9672 - loss: 0.1230 - val_accuracy: 0.9462 - val_loss: 0.2357
# Epoch 130/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9748 - loss: 0.0901 - val_accuracy: 0.9574 - val_loss: 0.1862
# Epoch 131/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9623 - loss: 0.1126 - val_accuracy: 0.9619 - val_loss: 0.1864
# Epoch 132/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9601 - loss: 0.1329 - val_accuracy: 0.9507 - val_loss: 0.1921
# Epoch 133/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9746 - loss: 0.0893 - val_accuracy: 0.9552 - val_loss: 0.1907
# Epoch 134/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9613 - loss: 0.0983 - val_accuracy: 0.9529 - val_loss: 0.1882
# Epoch 135/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9646 - loss: 0.1232 - val_accuracy: 0.9484 - val_loss: 0.2168
# Epoch 136/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9734 - loss: 0.0990 - val_accuracy: 0.9484 - val_loss: 0.2189
# Epoch 137/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9734 - loss: 0.0724 - val_accuracy: 0.9574 - val_loss: 0.1991
# Epoch 138/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9663 - loss: 0.0923 - val_accuracy: 0.9529 - val_loss: 0.1784
# Epoch 139/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9691 - loss: 0.1131 - val_accuracy: 0.9596 - val_loss: 0.1601
# Epoch 140/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9586 - loss: 0.1171 - val_accuracy: 0.9552 - val_loss: 0.1765
# Epoch 141/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9682 - loss: 0.0935 - val_accuracy: 0.9619 - val_loss: 0.1801
# Epoch 142/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9787 - loss: 0.0736 - val_accuracy: 0.9574 - val_loss: 0.1941
# Epoch 143/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9649 - loss: 0.1117 - val_accuracy: 0.9596 - val_loss: 0.1735
# Epoch 144/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9633 - loss: 0.1505 - val_accuracy: 0.9596 - val_loss: 0.1766
# Epoch 145/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9798 - loss: 0.0725 - val_accuracy: 0.9484 - val_loss: 0.2316
# Epoch 146/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9638 - loss: 0.0971 - val_accuracy: 0.9552 - val_loss: 0.2003
# Epoch 147/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9686 - loss: 0.1007 - val_accuracy: 0.9552 - val_loss: 0.1838
# Epoch 148/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9739 - loss: 0.0736 - val_accuracy: 0.9529 - val_loss: 0.2136
# Epoch 149/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9566 - loss: 0.1278 - val_accuracy: 0.9484 - val_loss: 0.2038
# Epoch 150/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9596 - loss: 0.1220 - val_accuracy: 0.9574 - val_loss: 0.2129
# Epoch 151/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9669 - loss: 0.1105 - val_accuracy: 0.9529 - val_loss: 0.1891
# Epoch 152/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9608 - loss: 0.1191 - val_accuracy: 0.9484 - val_loss: 0.2080
# Epoch 153/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9558 - loss: 0.1120 - val_accuracy: 0.9552 - val_loss: 0.1817
# Epoch 154/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9665 - loss: 0.0966 - val_accuracy: 0.9305 - val_loss: 0.2352
# Epoch 155/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9693 - loss: 0.0965 - val_accuracy: 0.9507 - val_loss: 0.2096
# Epoch 156/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9770 - loss: 0.0822 - val_accuracy: 0.9327 - val_loss: 0.2285
# Epoch 157/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9748 - loss: 0.0804 - val_accuracy: 0.9619 - val_loss: 0.1565
# Epoch 158/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9712 - loss: 0.0816 - val_accuracy: 0.9529 - val_loss: 0.1988
# Epoch 159/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9752 - loss: 0.0983 - val_accuracy: 0.9439 - val_loss: 0.2247
# Epoch 160/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9727 - loss: 0.0882 - val_accuracy: 0.9507 - val_loss: 0.2017
# Epoch 161/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9468 - loss: 0.1452 - val_accuracy: 0.9350 - val_loss: 0.2280
# Epoch 162/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9568 - loss: 0.1405 - val_accuracy: 0.9507 - val_loss: 0.1975
# Epoch 163/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9808 - loss: 0.0751 - val_accuracy: 0.9552 - val_loss: 0.1766
# Epoch 164/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9647 - loss: 0.1080 - val_accuracy: 0.9507 - val_loss: 0.1973
# Epoch 165/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9629 - loss: 0.1228 - val_accuracy: 0.9552 - val_loss: 0.1904
# Epoch 166/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9697 - loss: 0.1101 - val_accuracy: 0.9596 - val_loss: 0.1831
# Epoch 167/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9594 - loss: 0.1527 - val_accuracy: 0.9462 - val_loss: 0.2160
# Epoch 168/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9812 - loss: 0.0769 - val_accuracy: 0.9552 - val_loss: 0.1898
# Epoch 169/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9728 - loss: 0.0973 - val_accuracy: 0.9596 - val_loss: 0.1897
# Epoch 170/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9661 - loss: 0.1067 - val_accuracy: 0.9462 - val_loss: 0.2126
# Epoch 171/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9743 - loss: 0.1024 - val_accuracy: 0.9439 - val_loss: 0.2338
# Epoch 172/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9665 - loss: 0.1117 - val_accuracy: 0.9484 - val_loss: 0.1978
# Epoch 173/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9698 - loss: 0.0999 - val_accuracy: 0.9529 - val_loss: 0.1877
# Epoch 174/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9753 - loss: 0.0908 - val_accuracy: 0.9619 - val_loss: 0.1667
# Epoch 175/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9632 - loss: 0.1220 - val_accuracy: 0.9529 - val_loss: 0.2057
# Epoch 176/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9653 - loss: 0.1173 - val_accuracy: 0.9529 - val_loss: 0.1842
# Epoch 177/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9775 - loss: 0.0860 - val_accuracy: 0.9552 - val_loss: 0.1721
# Epoch 178/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9788 - loss: 0.0987 - val_accuracy: 0.9574 - val_loss: 0.1938
# Epoch 179/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9788 - loss: 0.0644 - val_accuracy: 0.9552 - val_loss: 0.2038
# Epoch 180/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9699 - loss: 0.1187 - val_accuracy: 0.9529 - val_loss: 0.2174
# Epoch 181/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9725 - loss: 0.0896 - val_accuracy: 0.9529 - val_loss: 0.2057
# Epoch 182/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9671 - loss: 0.0870 - val_accuracy: 0.9619 - val_loss: 0.1813
# Epoch 183/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9699 - loss: 0.0794 - val_accuracy: 0.9552 - val_loss: 0.1909
# Epoch 184/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9606 - loss: 0.1396 - val_accuracy: 0.9462 - val_loss: 0.2060
# Epoch 185/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9563 - loss: 0.1168 - val_accuracy: 0.9507 - val_loss: 0.2129
# Epoch 186/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9606 - loss: 0.1100 - val_accuracy: 0.9552 - val_loss: 0.1807
# Epoch 187/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9722 - loss: 0.0945 - val_accuracy: 0.9552 - val_loss: 0.1806
# Epoch 188/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9733 - loss: 0.1201 - val_accuracy: 0.9596 - val_loss: 0.1897
# Epoch 189/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9644 - loss: 0.0912 - val_accuracy: 0.9529 - val_loss: 0.1907
# Epoch 190/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9624 - loss: 0.0982 - val_accuracy: 0.9395 - val_loss: 0.2111
# Epoch 191/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9779 - loss: 0.0739 - val_accuracy: 0.9574 - val_loss: 0.1970
# Epoch 192/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9775 - loss: 0.1009 - val_accuracy: 0.9552 - val_loss: 0.1961
# Epoch 193/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9736 - loss: 0.0786 - val_accuracy: 0.9596 - val_loss: 0.1807
# Epoch 194/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9767 - loss: 0.0828 - val_accuracy: 0.9507 - val_loss: 0.2057
# Epoch 195/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9690 - loss: 0.0955 - val_accuracy: 0.9552 - val_loss: 0.1925
# Epoch 196/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9717 - loss: 0.0889 - val_accuracy: 0.9596 - val_loss: 0.1939
# Epoch 197/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9702 - loss: 0.0895 - val_accuracy: 0.9507 - val_loss: 0.2101
# Epoch 198/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9769 - loss: 0.0787 - val_accuracy: 0.9596 - val_loss: 0.1984
# Epoch 199/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9690 - loss: 0.1026 - val_accuracy: 0.9574 - val_loss: 0.1803
# Epoch 200/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9696 - loss: 0.0951 - val_accuracy: 0.9417 - val_loss: 0.2377
# Epoch 201/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9487 - loss: 0.1973 - val_accuracy: 0.9395 - val_loss: 0.2069
# Epoch 202/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9601 - loss: 0.1127 - val_accuracy: 0.9596 - val_loss: 0.1687
# Epoch 203/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9705 - loss: 0.1102 - val_accuracy: 0.9417 - val_loss: 0.2088
# Epoch 204/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9769 - loss: 0.0938 - val_accuracy: 0.9529 - val_loss: 0.1882
# Epoch 205/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9768 - loss: 0.0909 - val_accuracy: 0.9462 - val_loss: 0.1815
# Epoch 206/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9655 - loss: 0.1093 - val_accuracy: 0.9529 - val_loss: 0.2060
# Epoch 207/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9798 - loss: 0.0737 - val_accuracy: 0.9574 - val_loss: 0.1899
# Epoch 208/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9675 - loss: 0.0986 - val_accuracy: 0.9507 - val_loss: 0.2149
# Epoch 209/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9717 - loss: 0.0774 - val_accuracy: 0.9596 - val_loss: 0.1861
# Epoch 210/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9713 - loss: 0.1051 - val_accuracy: 0.9596 - val_loss: 0.1996
# Epoch 211/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9711 - loss: 0.0928 - val_accuracy: 0.9641 - val_loss: 0.1860
# Epoch 212/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9647 - loss: 0.0953 - val_accuracy: 0.9641 - val_loss: 0.1722
# Epoch 213/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9684 - loss: 0.1139 - val_accuracy: 0.9395 - val_loss: 0.2196
# Epoch 214/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9776 - loss: 0.0815 - val_accuracy: 0.9552 - val_loss: 0.2006
# Epoch 215/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9689 - loss: 0.1196 - val_accuracy: 0.9484 - val_loss: 0.2184
# Epoch 216/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9527 - loss: 0.1178 - val_accuracy: 0.9529 - val_loss: 0.1998
# Epoch 217/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9743 - loss: 0.0845 - val_accuracy: 0.9350 - val_loss: 0.2660
# Epoch 218/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9651 - loss: 0.1181 - val_accuracy: 0.9327 - val_loss: 0.2608
# Epoch 219/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9645 - loss: 0.1089 - val_accuracy: 0.9462 - val_loss: 0.2381
# Epoch 220/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9714 - loss: 0.1203 - val_accuracy: 0.9439 - val_loss: 0.2173
# Epoch 221/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9733 - loss: 0.0935 - val_accuracy: 0.9574 - val_loss: 0.1912
# Epoch 222/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9659 - loss: 0.1126 - val_accuracy: 0.9552 - val_loss: 0.2018
# Epoch 223/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9816 - loss: 0.0666 - val_accuracy: 0.9552 - val_loss: 0.2002
# Epoch 224/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9598 - loss: 0.1062 - val_accuracy: 0.9552 - val_loss: 0.1901
# Epoch 225/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9762 - loss: 0.0803 - val_accuracy: 0.9417 - val_loss: 0.2431
# Epoch 226/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9662 - loss: 0.0909 - val_accuracy: 0.9395 - val_loss: 0.2585
# Epoch 227/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9791 - loss: 0.0755 - val_accuracy: 0.9552 - val_loss: 0.1938
# Epoch 228/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9800 - loss: 0.0716 - val_accuracy: 0.9574 - val_loss: 0.2026
# Epoch 229/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9741 - loss: 0.0875 - val_accuracy: 0.9574 - val_loss: 0.2126
# Epoch 230/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9707 - loss: 0.0921 - val_accuracy: 0.9529 - val_loss: 0.2088
# Epoch 231/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9625 - loss: 0.1126 - val_accuracy: 0.9507 - val_loss: 0.2345
# Epoch 232/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9752 - loss: 0.0891 - val_accuracy: 0.9439 - val_loss: 0.2244
# Epoch 233/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9670 - loss: 0.1075 - val_accuracy: 0.9484 - val_loss: 0.2214
# Epoch 234/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9762 - loss: 0.0733 - val_accuracy: 0.9574 - val_loss: 0.1791
# Epoch 235/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9780 - loss: 0.0860 - val_accuracy: 0.9574 - val_loss: 0.1869
# Epoch 236/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9687 - loss: 0.1138 - val_accuracy: 0.9395 - val_loss: 0.2420
# Epoch 237/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9675 - loss: 0.1144 - val_accuracy: 0.9395 - val_loss: 0.2271
# Epoch 238/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9770 - loss: 0.0671 - val_accuracy: 0.9574 - val_loss: 0.1947
# Epoch 239/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9693 - loss: 0.0920 - val_accuracy: 0.9552 - val_loss: 0.1907
# Epoch 240/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9723 - loss: 0.0754 - val_accuracy: 0.9484 - val_loss: 0.1924
# Epoch 241/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9759 - loss: 0.0738 - val_accuracy: 0.9574 - val_loss: 0.2007
# Epoch 242/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9762 - loss: 0.0952 - val_accuracy: 0.9619 - val_loss: 0.1877
# Epoch 243/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9857 - loss: 0.0557 - val_accuracy: 0.9283 - val_loss: 0.2461
# Epoch 244/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9706 - loss: 0.0960 - val_accuracy: 0.9596 - val_loss: 0.1932
# Epoch 245/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9726 - loss: 0.1051 - val_accuracy: 0.9507 - val_loss: 0.1960
# Epoch 246/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9826 - loss: 0.0714 - val_accuracy: 0.9552 - val_loss: 0.2014
# Epoch 247/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9573 - loss: 0.1334 - val_accuracy: 0.9574 - val_loss: 0.1723
# Epoch 248/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9768 - loss: 0.0955 - val_accuracy: 0.9507 - val_loss: 0.1872
# Epoch 249/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9802 - loss: 0.0770 - val_accuracy: 0.9529 - val_loss: 0.2090
# Epoch 250/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9682 - loss: 0.0958 - val_accuracy: 0.9395 - val_loss: 0.2497
# Epoch 251/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9688 - loss: 0.1045 - val_accuracy: 0.9552 - val_loss: 0.1984
# Epoch 252/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9820 - loss: 0.0635 - val_accuracy: 0.9529 - val_loss: 0.1936
# Epoch 253/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9785 - loss: 0.0757 - val_accuracy: 0.9484 - val_loss: 0.2060
# Epoch 254/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9742 - loss: 0.0874 - val_accuracy: 0.9507 - val_loss: 0.2040
# Epoch 255/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9731 - loss: 0.0817 - val_accuracy: 0.9596 - val_loss: 0.1860
# Epoch 256/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9834 - loss: 0.0656 - val_accuracy: 0.9552 - val_loss: 0.1824
# Epoch 257/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9793 - loss: 0.0627 - val_accuracy: 0.9574 - val_loss: 0.1736
# Epoch 258/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9803 - loss: 0.0729 - val_accuracy: 0.9574 - val_loss: 0.2064
# Epoch 259/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9778 - loss: 0.0804 - val_accuracy: 0.9484 - val_loss: 0.1974
# Epoch 260/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9843 - loss: 0.0645 - val_accuracy: 0.9507 - val_loss: 0.2439
# Epoch 261/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9782 - loss: 0.0748 - val_accuracy: 0.9596 - val_loss: 0.1898
# Epoch 262/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9736 - loss: 0.1038 - val_accuracy: 0.9529 - val_loss: 0.1861
# Epoch 263/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9731 - loss: 0.0918 - val_accuracy: 0.9619 - val_loss: 0.1730
# Epoch 264/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9788 - loss: 0.0655 - val_accuracy: 0.9552 - val_loss: 0.1908
# Epoch 265/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9855 - loss: 0.0678 - val_accuracy: 0.9619 - val_loss: 0.1781
# Epoch 266/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9657 - loss: 0.0989 - val_accuracy: 0.9552 - val_loss: 0.1868
# Epoch 267/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9722 - loss: 0.0988 - val_accuracy: 0.9484 - val_loss: 0.2241
# Epoch 268/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9815 - loss: 0.0649 - val_accuracy: 0.9641 - val_loss: 0.1763
# Epoch 269/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9772 - loss: 0.0621 - val_accuracy: 0.9664 - val_loss: 0.1722
# Epoch 270/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9758 - loss: 0.0799 - val_accuracy: 0.9596 - val_loss: 0.1892
# Epoch 271/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9812 - loss: 0.0849 - val_accuracy: 0.9596 - val_loss: 0.2051
# Epoch 272/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9701 - loss: 0.1088 - val_accuracy: 0.9574 - val_loss: 0.1864
# Epoch 273/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9729 - loss: 0.0775 - val_accuracy: 0.9619 - val_loss: 0.1774
# Epoch 274/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9759 - loss: 0.0750 - val_accuracy: 0.9529 - val_loss: 0.1969
# Epoch 275/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9859 - loss: 0.0659 - val_accuracy: 0.9574 - val_loss: 0.1772
# Epoch 276/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9744 - loss: 0.0803 - val_accuracy: 0.9641 - val_loss: 0.1628
# Epoch 277/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9801 - loss: 0.0783 - val_accuracy: 0.9596 - val_loss: 0.1792
# Epoch 278/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9830 - loss: 0.0609 - val_accuracy: 0.9507 - val_loss: 0.2032
# Epoch 279/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9833 - loss: 0.0744 - val_accuracy: 0.9574 - val_loss: 0.2002
# Epoch 280/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9808 - loss: 0.0715 - val_accuracy: 0.9574 - val_loss: 0.2029
# Epoch 281/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9801 - loss: 0.0684 - val_accuracy: 0.9619 - val_loss: 0.1953
# Epoch 282/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9588 - loss: 0.1313 - val_accuracy: 0.9574 - val_loss: 0.1951
# Epoch 283/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9631 - loss: 0.1012 - val_accuracy: 0.9417 - val_loss: 0.2678
# Epoch 284/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9662 - loss: 0.1082 - val_accuracy: 0.9081 - val_loss: 0.4305
# Epoch 285/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9572 - loss: 0.1615 - val_accuracy: 0.9552 - val_loss: 0.2077
# Epoch 286/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9773 - loss: 0.0619 - val_accuracy: 0.9552 - val_loss: 0.1954
# Epoch 287/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9841 - loss: 0.0667 - val_accuracy: 0.9552 - val_loss: 0.2013
# Epoch 288/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9790 - loss: 0.0795 - val_accuracy: 0.9507 - val_loss: 0.2108
# Epoch 289/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9757 - loss: 0.0749 - val_accuracy: 0.9395 - val_loss: 0.2424
# Epoch 290/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9640 - loss: 0.1075 - val_accuracy: 0.9596 - val_loss: 0.1977
# Epoch 291/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9608 - loss: 0.1141 - val_accuracy: 0.9529 - val_loss: 0.2151
# Epoch 292/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9734 - loss: 0.1001 - val_accuracy: 0.9417 - val_loss: 0.2394
# Epoch 293/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9840 - loss: 0.0545 - val_accuracy: 0.9529 - val_loss: 0.2136
# Epoch 294/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9753 - loss: 0.0751 - val_accuracy: 0.9596 - val_loss: 0.2048
# Epoch 295/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9636 - loss: 0.1195 - val_accuracy: 0.9484 - val_loss: 0.2116
# Epoch 296/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9743 - loss: 0.0817 - val_accuracy: 0.9529 - val_loss: 0.2000
# Epoch 297/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9727 - loss: 0.0778 - val_accuracy: 0.9507 - val_loss: 0.2015
# Epoch 298/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9774 - loss: 0.0683 - val_accuracy: 0.9462 - val_loss: 0.2263
# Epoch 299/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9837 - loss: 0.0807 - val_accuracy: 0.9439 - val_loss: 0.2236
# Epoch 300/300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9690 - loss: 0.1218 - val_accuracy: 0.9417 - val_loss: 0.2330
